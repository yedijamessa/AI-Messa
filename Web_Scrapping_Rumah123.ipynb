# %% [markdown]
# <a href="https://colab.research.google.com/github/yedijamessa/AI-Messa/blob/main/Web_Scrapping_Rumah123.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# LAMUDI - Cannot

# %%
# URL of the website (you need to replace with the actual URL)
url = 'https://www.lamudi.co.id/newdevelopments/lamudi-projects-agn/grand-tenjo-residence-1/'

# Set up the headers with a User-Agent
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
}

# Make the request with the headers
response = requests.get(url, headers=headers)

# %%
# If the status code is 200, the request was successful
if response.status_code == 200:

    # Parse the HTML content
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find all the 'li' elements with class 'Card' containing the price info
    card_items = soup.find_all('li', class_='Card')

    # Loop through each 'li' element to find the price within a 'span' with class 'value'
    for card in card_items:
        price_container = card.find('div', class_='Card-info-pricetype')

        # Check if the price container is found
        if price_container:
            price_value = price_container.find('span', class_='value')

            # If the price value is found, print it
            if price_value:
                print(price_value.text.strip())
            else:
                print("Price value not found in the container.")
        else:
            print("Price container not found.")
else:
    print(f"Failed to retrieve the webpage, status code: {response.status_code}")
# Out:
# Failed to retrieve the webpage, status code: 403

# %% [markdown]
# RUMAH123

# %%
import requests
from bs4 import BeautifulSoup

# Replace with the actual URL you want to scrape
url = 'https://www.rumah123.com/explore/kota-yogyakarta/'

# Set up the headers with a User-Agent
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
}

# Make the request with the headers
response = requests.get(url, headers=headers)

# Check if the request was successful
if response.status_code == 200:
    # Create a BeautifulSoup object and specify the parser
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find all elements with the specified class
    price_elements = soup.find_all('strong', class_='ui-explore-listing__property-price')

    # Loop through all found elements and print their text content
    for price in price_elements:
        print(price.text.strip())  # .strip() removes leading/trailing whitespace
else:
    print(f"Failed to retrieve the webpage, status code: {response.status_code}")
# Out:
# Rp 1,7 Miliar
# Rp 927 Juta
# Rp 863 Juta
# Rp 1,47 Miliar
# Rp 300 Miliar
# Rp 1,2 Miliar
# Rp 985 Juta
# Rp 454 Juta
# Rp 2,49 Miliar
# Rp 950 Juta
# Rp 62 Juta per tahun
# Rp 50 Juta per tahun
# Rp 115 Juta per tahun
# Rp 195 Juta per tahun
# Rp 155 Juta per tahun
# Rp 250 Juta per tahun
# Rp 75 Juta per tahun
# Rp 68 Juta per tahun
# Rp 125 Juta per tahun
# Rp 125 Juta per tahun

# %%
import requests
from bs4 import BeautifulSoup

# Replace with the actual URL you want to scrape
url = 'https://www.rumah123.com/jual/yogyakarta/rumah/?minPrice=null&maxPrice=null'

# Set up the headers with a User-Agent to mimic a browser
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
}

# Make the request with the headers
response = requests.get(url, headers=headers)

# Check if the request was successful
if response.status_code == 200:
    # Create a BeautifulSoup object and specify the parser
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find all elements with the specified class
    price_elements = soup.find_all('div', class_='card-featured__middle-section__price')

    # Loop through all found elements and print their text content
    for price_section in price_elements:
        price = price_section.find('strong')
        if price:
            print(price.text.strip())  # .strip() removes leading/trailing whitespace
        else:
            print("Price element not found.")
else:
    print(f"Failed to retrieve the webpage, status code: {response.status_code}")
# Out:
# Rp 1,7 Miliar
# Rp 927 Juta
# Rp 863 Juta
# Rp 1,47 Miliar
# Rp 300 Miliar
# Rp 1,2 Miliar
# Rp 985 Juta
# Rp 454 Juta
# Rp 2,49 Miliar
# Rp 950 Juta
# Rp 868 Juta
# Rp 2,35 Miliar
# Rp 1,7 Miliar
# Rp 1,7 Miliar
# Rp 690 Juta
# Rp 2,37 Miliar
# Rp 2,04 Miliar
# Rp 848 Juta
# Rp 848 Juta
# Rp 877 Juta

# %%
import requests
from bs4 import BeautifulSoup

# Base URL of the website without the page number
base_url = 'https://www.rumah123.com/jual/yogyakarta/rumah/?minPrice=null&maxPrice=null'

# Set up the headers with a User-Agent to mimic a browser
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
}

# Define the number of pages you want to scrape
number_of_pages = 10  # for example, if you want to scrape 10 pages

# Loop through the specified range of pages
for page in range(1, number_of_pages + 1):
    # Append the page number to the base URL
    url = f"{base_url}&page={page}"
    print(f"Scraping {url}")

    # Make the request with the headers
    response = requests.get(url, headers=headers)

    # Check if the request was successful
    if response.status_code == 200:
        # Create a BeautifulSoup object and specify the parser
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find all elements with the specified class
        price_elements = soup.find_all('div', class_='card-featured__middle-section__price')

        # Loop through all found elements and print their text content
        for price_section in price_elements:
            price = price_section.find('strong')
            if price:
                print(price.text.strip())  # .strip() removes leading/trailing whitespace
            else:
                print("Price element not found.")
    else:
        print(f"Failed to retrieve the webpage, status code: {response.status_code}")
# Out:
# Scraping https://www.rumah123.com/jual/yogyakarta/rumah/?minPrice=null&maxPrice=null&page=1
# Rp 1,7 Miliar
# Rp 927 Juta
# Rp 863 Juta
# Rp 1,47 Miliar
# Rp 300 Miliar
# Rp 1,2 Miliar
# Rp 985 Juta
# Rp 454 Juta
# Rp 2,49 Miliar
# Rp 950 Juta
# Rp 868 Juta
# Rp 2,35 Miliar
# Rp 1,7 Miliar
# Rp 1,7 Miliar
# Rp 690 Juta
# Rp 2,37 Miliar
# Rp 2,04 Miliar
# Rp 848 Juta
# Rp 848 Juta
# Rp 877 Juta
# Scraping https://www.rumah123.com/jual/yogyakarta/rumah/?minPrice=null&maxPrice=null&page=2
# Rp 550 Juta
# Rp 2,04 Miliar
# Rp 1,5 Miliar
# Rp 1,87 Miliar
# Rp 1,3 Miliar
# Rp 1,5 Miliar
# Rp 42 Miliar
# Rp 3,25 Miliar
# Rp 750 Juta
# Rp 16 Miliar
# Rp 2,1 Miliar
# Rp 1,35 Miliar
# Rp 40 Miliar
# Rp 1 Miliar
# Rp 2,4 Miliar
# Rp 1 Miliar
# Rp 1,1 Miliar
# Rp 985 Juta
# Rp 594 Juta
# Rp 594 Juta
# Scraping https://www.rumah123.com/jual/yogyakarta/rumah/?minPrice=null&maxPrice=null&page=3
# Rp 594 Juta
# Rp 594 Juta
# Rp 1,82 Miliar
# Rp 1,82 Miliar
# Rp 1,1 Miliar
# Rp 2,9 Miliar
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Function to get the total number of pages
def get_total_pages(url):
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        pagination_container = soup.find('ul', class_='ui-molecule-paginate')
        if pagination_container:
            page_links = pagination_container.find_all('a', href=True)
            last_page_link = page_links[-2]['href']
            number_of_pages = int(last_page_link.split('page=')[1])
            return number_of_pages
    return 0

# Function to scrape prices from a single page
def scrape_prices_from_page(url):
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        price_elements = soup.find_all('div', class_='card-featured__middle-section__price')
        prices = [price.find('strong').text.strip() for price in price_elements if price.find('strong')]
        return prices
    return []

# The base URL for the first page of listings
base_url = 'https://www.rumah123.com/jual/yogyakarta/rumah/?minPrice=null&maxPrice=null'

# Set up the headers with a User-Agent to mimic a browser
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
}

# Get the total number of pages from the website
total_pages = get_total_pages(base_url)

# List to store all prices
all_prices = []

# Loop through all pages and scrape the prices
for page in range(1, total_pages + 1):
    page_url = f"{base_url}&page={page}"
    prices_on_page = scrape_prices_from_page(page_url)
    all_prices.extend(prices_on_page)

# Create a DataFrame with the prices
df_prices = pd.DataFrame(all_prices, columns=['Price'])

# # Output the DataFrame
# print(df_prices)

# # Optionally, save the DataFrame to a CSV file
# df_prices.to_csv('property_prices.csv', index=False)

# %%
df_prices
# Out:
#                Price
# 0      Rp 1,7 Miliar
# 1        Rp 927 Juta
# 2        Rp 863 Juta
# 3     Rp 1,47 Miliar
# 4      Rp 300 Miliar
# ...              ...
# 4352   Rp 2,9 Miliar
# 4353   Rp 3,7 Miliar
# 4354  Rp 1,69 Miliar
# 4355   Rp 2,5 Miliar
# 4356   Rp 1,3 Miliar
#
# [4357 rows x 1 columns]

# %% [markdown]
# PINHOME

# %%
import requests
from bs4 import BeautifulSoup

# Replace with the actual URL you want to scrape
url = 'https://www.pinhome.id/'

# Set up the headers with a User-Agent
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
}

# Make the request with the headers
response = requests.get(url, headers=headers)

# Check if the request was successful
if response.status_code == 200:
    # Create a BeautifulSoup object and specify the parser
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find all elements with the specified class
    price_elements = soup.find_all('div', class_='pin-card__pricing___kxwdv pin-card__ellipsis___xqz18')

    # Loop through all found elements and print their text content
    for price in price_elements:
        print(price.text.strip())  # .strip() removes leading/trailing whitespace
else:
    print(f"Failed to retrieve the webpage, status code: {response.status_code}")
# Out:
# R
# %%
import requests
from bs4 import BeautifulSoup

# Replace with the actual URL you want to scrape
url = 'https://rumah.mitula.co.id/rumah/jakarta'

# Set up the headers with a User-Agent
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
}

# Make the request with the headers
response = requests.get(url, headers=headers)

# Check if the request was successful
if response.status_code == 200:
    # Create a BeautifulSoup object and specify the parser
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find all elements with the specified class
    price_elements = soup.find_all('div', class_='price')

    # Loop through all found elements and print their text content
    for price in price_elements:
        print(price.text.strip())  # .strip() removes leading/trailing whitespace
else:
    print(f"Failed to retrieve the webpage, status code: {response.status_code}")
# Out:
# Rp. 6.500.000.000
# Rp. 12.000.000.000
# Rp. 2.320.000.000
# Rp. 2.500.000.000
# Rp. 28.788.000.000
# Rp. 13.000.000.000
# Rp. 32.700.000.000
# Rp. 160.000.000
# Rp. 3.680.000.000
# Rp. 19.700.000.000
# Rp. 1.250.000.000
# Rp. 16.100.000.000
# Rp. 60.000.000.000
# Rp. 1.425.000.000
# Rp. 2.785.000.000
# Rp. 2.500.000.000
# Rp. 12.400.000.000
# Rp. 5.000.000.000
# Rp. 1.800.000.000
# Rp. 1.250.000.000
# Rp. 1.450.000.000
# Rp. 2.500.000.000
# Rp. 4.000.000.000
# Rp. 4.900.000.000
# Rp. 3.900.000.000
# Rp. 1.950.000.000
# Rp. 1.700.000.000
# Rp. 2.550.000.000
# Rp. 1.078.405.500
# Rp. 2.750.000.000

# %% [markdown]
# Trovit

# %%
import requests
from bs4 import BeautifulSoup

# Replace with the actual URL you want to scrape
url = 'https://rumah.trovit.co.id/jakarta-barat'

# Set up the headers with a User-Agent
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
}

# Make the request with the headers
response = requests.get(url, headers=headers)

# Check if the request was successful
if response.status_code == 200:
    # Create a BeautifulSoup object and specify the parser
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find all elements with the specified class
    price_elements = soup.find_all('span', class_='actual-price')

    # Loop through all found elements and print their text content
    for price in price_elements:
        print(price.text.strip())  # .strip() removes leading/trailing whitespace
else:
    print(f"Failed to retrieve the webpage, status code: {response.status_code}")
# Out:
# Rp 1,480,000,000
# Rp 4,600,000,000
# Rp 4,800,000,000
# Rp 3,700,000,000
# Rp 1,490,000,000
# Rp 2,700,000,000
# Rp 4,100,000,000
# Rp 13,500,000,000
# Rp 4,300,000,000
# Rp 4,000,000,000
# Rp 7,000,000,000
# Rp 1,600,000,000
# Rp 1,600,000,000
# Rp 850,000,000
# Rp 3,500,000,000
# Rp 800,000,000
# Rp 956,000,000
# Rp 1,200,000,000
# Rp 5,400,000,000
# Rp 1,768,000,000
# Rp 1,700,000,000
# Rp 1,950,000,000
# Rp 1,900,000,000
# Rp 2,600,000,000
# Rp 10,500,000,000

# %% [markdown]
# Brighton - Can't

# %%
import requests
from bs4 import BeautifulSoup

# Replace with the actual URL you want to scrape
url = 'https://www.brighton.co.id/'

# Set up the headers with a User-Agent
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
}

# Make the request with the headers
response = requests.get(url, headers=headers)

# Check if the request was successful
if response.status_code == 200:
    # Create a BeautifulSoup object and specify the parser
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find all elements with the specified class
    price_elements = soup.find_all('p', class_='harga-proyek-baru')

    # Loop through all found elements and print their text content
    for price in price_elements:
        print(price.text.strip())  # .strip() removes leading/trailing whitespace
else:
    print(f"Failed to retrieve the webpage, status code: {response.status_code}")
# Out:
# Rp {{ item.PriceFormat }}

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import time

# Set up Selenium with ChromeDriver
chrome_options = Options()
chrome_options.add_argument("--headless")  # Run in headless mode (no browser UI)
s = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=s, options=chrome_options)

# Replace with the actual URL you want to scrape
url = 'https://www.brighton.co.id/'

# Navigate to the page
driver.get(url)

# Wait for JavaScript to load
time.sleep(5)  # This might need to be adjusted

# Find all elements with the specified class
price_elements = driver.find_elements(By.CLASS_NAME, 'harga-proyek-baru')

# Loop through all found elements and print their text content
for price in price_elements:
    print(price.text)  # No need to strip as Selenium handles it

# Close the browser
driver.quit()
# Out:
#   File "<ipython-input-9-ce030de07cf4>", line 1
#     pip install selenium webdriver-manager
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# Onlist

# %%
import requests
from bs4 import BeautifulSoup

# Replace with the actual URL you want to scrape
url = 'https://onlist.id/jual/rumah?neLat=-6.061095860502775&neLng=107.06750230864452&swLat=-6.443794734780923&swLng=106.5887907007936'

# Set up the headers with a User-Agent
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
}

# Make the request with the headers
response = requests.get(url, headers=headers)

# Check if the request was successful
if response.status_code == 200:
    # Create a BeautifulSoup object and specify the parser
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find all elements with the specified class
    price_elements = soup.find_all('label', class_='price')

    # Loop through all found elements and print their text content
    for price in price_elements:
        print(price.text.strip())  # .strip() removes leading/trailing whitespace
else:
    print(f"Failed to retrieve the webpage, status code: {response.status_code}")
# Out:
# IDR 39.500.000.000
# IDR 7.900.000.000
# IDR 8.500.000.000
# IDR 4.300.000.000
# IDR 2.850.000.000
# IDR 7.000.000.000
