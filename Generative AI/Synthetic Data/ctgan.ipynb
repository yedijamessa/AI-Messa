# %%
from ctgan import CTGAN
from ctgan import load_demo

real_data = load_demo()

# Names of the columns that are discrete
discrete_columns = [
    'workclass',
    'education',
    'marital-status',
    'occupation',
    'relationship',
    'race',
    'sex',
    'native-country',
    'income'
]

ctgan = CTGAN(epochs=10)
ctgan.fit(real_data, discrete_columns)

# Create synthetic data
synthetic_data = ctgan.sample(1000)

# %%
synthetic_data
# Out:
#      age    workclass  fnlwgt     education  education-num  \
# 0     51    State-gov  491232    Assoc-acdm              9
# 1     30      Private  123985     Assoc-voc              9
# 2     47      Private  272624       HS-grad              9
# 3     29      Private  125370  Some-college              9
# 4     32  Federal-gov  171381       HS-grad              9
# ..   ...          ...     ...           ...            ...
# 995   17    Local-gov  262783  Some-college              9
# 996   28      Private  465209          10th             11
# 997   50  Federal-gov  127742       HS-grad              9
# 998   30      Private  204867       HS-grad              9
# 999   48      Private  275377       HS-grad              9
#
#          marital-status         occupation   relationship                race  \
# 0              Divorced    Exec-managerial  Not-in-family               White
# 1         Never-married  Machine-op-inspct      Own-child               Black
# 2         Never-married    Exec-managerial  Not-in-family               White
# 3    Married-civ-spouse       Adm-clerical      Own-child               Black
# 4    Married-civ-spouse              Sales        Husband               White
# ..                  ...                ...            ...                 ...
# 995  Married-civ-spouse    Farming-fishing      Unmarried  Asian-Pac-Islander
# 996  Married-civ-spouse       Tech-support  Not-in-family               Black
# 997  Married-civ-spouse              Sales        Husband               White
# 998  Married-civ-spouse      Other-service      Unmarried               Black
# 999  Married-civ-spouse   Transport-moving        Husband               Black
#
#         sex  capital-gain  capital-loss  hours-per-week native-country income
# 0      Male            95             6              28  United-States  <=50K
# 1      Male            76            -3              32  United-States  <=50K
# 2    Female           121             0              50  United-States  <=50K
# 3    Female            67            -3              16  United-States  <=50K
# 4      Male           -29            -5              13  United-States  <=50K
# ..      ...           ...           ...             ...            ...    ...
# 995    Male          9704            -1              34  United-States  <=50K
# 996    Male            40             1              33  United-States  <=50K
# 997    Male            -3             4              28  United-States  <=50K
# 998  Female           136            -2              44  United-States   >50K
# 999  Female           123             2              48       Portugal  <=50K
#
# [1000 rows x 15 columns]
